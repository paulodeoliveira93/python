# %% [markdown]
# # Estruturas de decisão
#
# <span style="color: red;"><b>Todos os exercícios são feitos partindo-se do pressuposto de que todas as entradas são dadas de forma correta. Casos limite não mencionados no enunciado não são abordados porque não fazem parte do exercício.</b></span>

# %% [markdown]
# #### 1. Faça um Programa que peça dois números e imprima o maior deles.

# %%
num1 = input('Digite um numero qualquer: ')
num2 = input('Digite um numero qualquer: ')

if num1 and num2:
    num1 = int(num1)
    num2 = int(num2)
    if num1 > num2:
        print('O primeiro número que você digitou é o maior. Você digitou o número {} .' .format(num1))
    if num2 > num1:
        print('O segundo número que você digitou é o maior. Você digitou o número {} .' .format(num2))
    if num2 == num1:
        print('Os números que você digitou são iguais. Você digitou o número {} .' .format(num2))

else:
    print('ERRO!! Preencha todas os campos!!')
# Out:
# Os números que você digitou são iguais. Você digitou o número 0 .

# %% [markdown]
# #### 2. Faça um Programa que peça um valor e mostre na tela se o valor é positivo ou negativo.

# %%
numero = input('Digite um numero qualquer: ')


if numero:
    numero = int(numero)
    if numero > 0:
        print('O número é positivo. Você digitou o número {} .' .format(numero))
    if numero < 0:
        print('O número é negativo. Você digitou o número {} .' .format(numero))
    if numero == 0:
        print('O número que você digitou foi o zero.')    
else:
    print('ERRO!! Preencha todas os campos!!')
# Out:
# O número que você digitou foi o zero.

# %% [markdown]
# #### 3. Faça um Programa que verifique o estado civil de uma pessoa. Se a letra digitada é "C" (Casado), "S" (Solteiro), "D" (Divorciado), "V" (Viúvo) ou "O" (outros). Conforme a letra escrita pelo usuário seu programa deve escrever o estado civil, exemplo:
#
# Usuário digita: C
#
# Seu programa deve responder:
# C - Casado

# %%
estado_civil = input('Qual o seu estado civil: ')

if estado_civil:
    if estado_civil == 'C':
        print('C - Casado')
    if estado_civil == 'S':
        print('S - Solteiro')
    if estado_civil == 'D':
        print('D - Divorciado')
    if estado_civil == 'V':
        print('V - Viuvo')
    if estado_civil == 'O':
        print('O - Outros')
else:
    print('ERRO!! Preencha todas os campos!!')

# %% [markdown]
# #### 4. Faça um Programa que verifique se o e-mail digitado faz parte dos e-mails de spam.

# %%
emails_spam = "fulano@gmail.com,beltrano@gmail.com,ciclano@gmail.com"
email = input('Digite o email')

if email:
    if email in emails_spam:
        print('Este email é spam!')
    else:
        print('Esse email não e spam')
else:
    print('ERRO!! Preencha todas os campos!!')
# Out:
# Esse email não e spam

# %% [markdown]
# #### 5. Faça um programa para a leitura de duas notas parciais de um aluno. O programa deve calcular a média alcançada por aluno e apresentar:
#
# ##### A mensagem "Aprovado", se a média alcançada for maior ou igual a sete;
# ##### A mensagem "Reprovado", se a média for menor do que sete;
# ##### A mensagem "Aprovado com Distinção", se a média for igual a dez.

# %%
nota1 = float ((input('Digite a primeira nota')))
nota2 = float ((input('Digite a segunda nota')))
media = (nota1 + nota2) / 2
status = 7

if nota1 and nota2:
    media = float(media)
    if media == 10:
        print('Aprovado com distinção. Sua média foi {} .' .format(media))
    elif media > status:
        print('Aprovado. Sua média foi {} .' .format(media))
    else:
        print('Reprovado. Sua média foi {} .' .format(media))
else:
    print('ERRO!! Preencha todas os campos!!')
# Out:
# ERRO!! Preencha todas os campos!!

# %% [markdown]
# #### 6. Faça um Programa que leia o orçamento de 3 empresas e mostre o maior deles.

# %%
orcamento1 = input('Digite o valor do primeiro orçamento: ')
orcamento2 = input('Digite o valor do segundo orçamento: ')
orcamento3 = input('Digite o valor do terceiro orçamento: ')

if orcamento1 and orcamento2 and orcamento3:
    if orcamento1 > orcamento2 and orcamento1 > orcamento3:
        print('O maior orçamento é o primeiro. Seu valor é de {} reais' .format(orcamento1))
    if orcamento2 > orcamento1 and orcamento2 > orcamento3:
        print('O mai0or orçamento  é o segundo. Seu valor é de {} reais' .format(orcamento2))
    if orcamento3 > orcamento1 and orcamento3 > orcamento2:
        print('O maior orçamento é o terceiro. Seu valor é de {} reais' .format(orcamento3))
else:
    print('ERRO!! Preencha todos os campos!')

# %% [markdown]
# #### 7. Faça um Programa que leia três orçamentos e mostre o maior e o menor deles.

# %%
orcamento1 = input('Digite o valor do primeiro orçamento: ')
orcamento2 = input('Digite o valor do segundo orçamento: ')
orcamento3 = input('Digite o valor do terceiro orçamento: ')

if orcamento1 and orcamento2 and orcamento3:
    print('O primeiro orçamento é de {} reais.' .format(orcamento1))
    print('O segundo orçamento é de {} reais.' .format(orcamento2))
    print('O terceiro orçamento é de {} reais.' .format(orcamento3))

    if orcamento1 > orcamento2 and orcamento1 > orcamento3:
        print('O maior orçamento é o primeiro. Seu valor é de {} reais' .format(orcamento1))
    if orcamento2 > orcamento1 and orcamento2 > orcamento3:
        print('O maior orçamento é o segundo. Seu valor é de {} reais' .format(orcamento2))
    if orcamento3 > orcamento1 and orcamento3 > orcamento2:
        print('O maior orçamento é o terceiro. Seu valor é de {} reais' .format(orcamento3))

    if orcamento1 < orcamento2 and orcamento1 < orcamento3:
        print('O menor orçamento é o primeiro. Seu valor é de {} reais.' .format(orcamento1))
    if orcamento2 < orcamento1 and orcamento2 < orcamento3:
        print('O menor orçamento é o segundo. Seu valor é de {} reais.' .format(orcamento2))
    if orcamento3 < orcamento1 and orcamento3 < orcamento2:
        print('O menor orçamento é o terceiro. Seu valor é de {} reais.' .format(orcamento3))
else:
    print('ERRO!! Preencha todos os campos!')
# Out:
# ERRO!! Preencha todos os campos!

# %% [markdown]
# #### 8. Faça um programa que pergunte o preço de três produtos e informe qual produto você deve comprar, sabendo que a decisão é sempre pelo mais barato.

# %%
produto1 = float(input('Digite o preço do primeiro produto: '))
produto2 = float(input('Digite o preço do segundo produto: '))
produto3 = float(input('Digite o preço do terceiro produto: '))

if produto1 and produto2 and produto3:
    if produto1 < produto2 and produto1 < produto3:
        print('O produto mais barato é o primeiro. O produto 1 custa {} R$.' .format(produto1))
    if produto2 < produto1 and produto2 < produto3:
        print('O produto mais barato é o segundo. O produto 2 custa {} R$.' .format(produto2))
    if produto3 < produto1 and produto3 < produto2:
        print('O produto mais barato é o terceiro. O produto 3 custa {} R$.' .format(produto3))

else:
    print('ERRO!! Preencha todos os campos!')
# Out:
# O produto mais barato é o terceiro. O produto 1 custa 10.0 R$.

# %% [markdown]
# #### 9. Faça um Programa que leia três números e mostre-os em ordem decrescente.

# %%
numero1 = float(input('Digite o primeiro número: '))
numero2 = float(input('Digite o segundo número: '))
numero3 = float(input('Digite o terceiro número: '))

if numero1 and numero2 and numero3:
    print(f'O número 1 é {numero1}')
    print(f'O número 2 é {numero2}')
    print(f'O número 3 é {numero3}')
    if numero3 > numero2 and numero2 > numero1:
        print('A ordem descrecente é: {}, {}, {}.' .format(numero3, numero2, numero1))
    if numero2 > numero3 and numero3 > numero1:
        print('A ordem descrecente é: {}, {}, {}.' .format(numero2, numero1, numero3))
    if numero1 > numero2 and numero2 > numero3:
        print('A ordem descrecente é: {}, {}, {}.' .format(numero1, numero2, numero3))
else:
    print('ERRO!! Preencha todos os campos!')
# Out:
# O número 1 é 30.0
# O número 2 é 50.0
# O número 3 é 60.0
# A ordem descrecente é: 60.0, 50.0, 30.0.

# %% [markdown]
# #### 10. Faça um Programa que pergunte em que turno você estuda. Peça para digitar M-matutino ou V-Vespertino ou N- Noturno. Imprima a mensagem "Bom Dia!", "Boa Tarde!" ou "Boa Noite!" ou "Valor Inválido!", conforme o caso.

# %%
turno = input('Digite qual turno vc estuda: ')

if turno:
    if turno == 'M':
        print('Bom dia!')
    if turno == 'V':
        print('Boa Tarde!')
    if turno == 'N':
        print('Boa Noite!')
else:
    print('ERRO!! Preencha todos os campos!')

# %% [markdown]
# #### 11. As Organizações Tabajara resolveram dar um aumento de salário aos seus colaboradores e lhe contraram para desenvolver o programa que calculará os reajustes. Faça um programa que recebe o salário de um colaborador e o reajuste segundo o seguinte critério, baseado no salário atual:
#
# ##### salários até R\\$ 280,00 (incluindo) : aumento de 20%
#
# ##### salários entre R\\$ 280,00 e R\\$ 700,00 : aumento de 15%
#
# ##### salários entre R\\$ 700,00 e R\\$ 1500,00 : aumento de 10%
#
# ##### salários de R\\$ 1500,00 em diante : aumento de 5% Após o aumento ser realizado, informe na tela:
#
# ###### o salário antes do reajuste;
#
# ###### o percentual de aumento aplicado;
#
# ###### o valor do aumento;
#
# ###### o novo salário, após o aumento.
#
# ###### Obs: Não vamos nos preocupar tanto com a formatação dos números (nº de casas decimais, por exemplo, veremos isso no próximo módulo)

# %%
salario = float(input('Digite o seu salário: '))

if salario:
    if salario <= 280:
        percentual = 0.2
    elif salario <= 700:
        percentual = 0.15
    elif salario <= 1500:
        percentual = 0.1
    else:
         percentual = 0.05
    
    novo_salario =  salario * (1 + percentual)
    valor_aumentado = novo_salario - salario
    print(f'O salário antes do aumento é de: {salario} R$')
    print(f'O aumento foi de {percentual * 100} %')
    print(f'O valor do aumento foi de {valor_aumentado} R$')
    print(f'O seu novo salário é de {novo_salario} R$')
else:
    print('ERRO!! Preencha todos os campos!')
# Out:
# O salário antes do aumento é de: 2700.0 R$
# O aumento foi de 5.0 %
# O valor do aumento foi de 135.0 R$
# O seu novo salário é de 2835.0 R$

# %% [markdown]
# #### 12 . Faça um programa para o cálculo de uma folha de pagamento, sabendo que os descontos são do Imposto de Renda, que depende do salário bruto (conforme tabela abaixo) e 3% para o Sindicato e que o FGTS corresponde a 11% do Salário Bruto, mas não é descontado (é a empresa que deposita). O Salário Líquido corresponde ao Salário Bruto menos os descontos. O programa deverá pedir ao usuário o valor da sua hora e a quantidade de horas trabalhadas no mês.
#
# Desconto do IR:<br>
# Salário Bruto até 900 (inclusive) - isento<br>
# Salário Bruto até 1500 (inclusive) - desconto de 5%<br>
# Salário Bruto até 2500 (inclusive) - desconto de 10%<br>
# Salário Bruto acima de 2500 - desconto de 20%<br>
# Imprima na tela as informações, dispostas conforme o exemplo abaixo. No exemplo o valor da hora é 5 e a quantidade de hora é 220.
#
# Salário Bruto: (5 * 220)        : R\\$ 1100,00<br>
# (-) IR (5%)                     : R\\$   55,00<br>
# (-) INSS ( 10%)                 : R\\$  110,00<br>
# FGTS (11%)                      : R\\$  121,00<br>
# Total de descontos              : R\\$  165,00<br>
# Salário Liquido                 : R\\$  935,00<br>
#
# ###### Obs: Não vamos nos preocupar tanto com a formatação dos números (nº de casas decimais, por exemplo, veremos isso no próximo módulo)

# %%
valor_hora = float(input('Digite o valor de quanto vc ganha por hora: '))
salario_bruto = valor_hora * 220
inss = 0.1
fgts = 0.11
if valor_hora:
    if salario_bruto <= 900:
        ir = 0
    elif salario_bruto <= 1500:
        ir = 0.05
    elif salario_bruto <= 2500:
        ir = 0.1
    elif salario_bruto > 2500:
        ir = 0.2 
else:
    print('ERRO!! Preencha todos os campos!')
print(f'O salario bruto é: {salario_bruto} R$')
print(f'O desconto do IR é de {ir * 100} %. No valor de {ir * salario_bruto} R$')
print(f'O desconto do INSS é de {inss * 100} %. No valor de {inss * salario_bruto} R$')
print(f'O desconto do FGTS é de {fgts * 100} %. No valor de {fgts * salario_bruto} R$')
print(f'O salario liquido é de {(ir * salario_bruto) + (inss * salario_bruto) + (fgts * salario_bruto)} R$')
print(f'O salario liquido é de {salario_bruto - (ir * salario_bruto) - (inss * salario_bruto) - (fgts * salario_bruto)} R$')
# Out:
# O salario bruto é: 3300.0 R$
# O desconto do IR é de 20.0 %. No valor de 660.0 R$
# O desconto do INSS é de 10.0 %. No valor de 330.0 R$
# O desconto do FGTS é de 11.0 %. No valor de 363.0 R$
# O salario liquido é de 1353.0 R$
# O salario liquido é de 1947.0 R$

# %% [markdown]
# #### 13. Faça um Programa que leia um número e exiba o dia correspondente da semana. (1-Domingo, 2- Segunda, etc.), se digitar outro valor deve aparecer valor inválido.

# %%
dia = int(input('Digite o numero da semana: '))

if  dia == 1:
    dia_da_semana ='Domingo'
elif dia == 2:
    dia_da_semana = 'Segunda'
elif dia == 3:
    dia_da_semana = 'Terça'
elif dia == 4:
    dia_da_semana = 'Quarta'
elif dia == 5:
    dia_da_semana = 'Quinta'
elif dia == 6:
    dia_da_semana = 'Sexta'    
elif dia == 7:
    dia_da_semana = 'Sábado'
else:
    dia_da_semana = 'Valor inválido'

print(dia_da_semana)
# Out:
# Valor inválido

# %% [markdown]
# #### 14. Faça um programa que lê as duas notas parciais obtidas por um aluno numa disciplina ao longo de um semestre, e calcule a sua média. Em seguida, mostre qual conceito o aluno teve. A atribuição de conceitos obedece à tabela abaixo:
# <pre>
# Média de Aproveitamento  Conceito
# Entre 9.0 e 10.0        A
# Entre 7.5 e 9.0         B
# Entre 6.0 e 7.5         C
# Entre 4.0 e 6.0         D
# Entre 4.0 e zero        E
# </pre>

# %%
nota1 = float(input('Digite a primeira nota aqui: '))
nota2 = float(input('Digite a segunda nota aqui: '))

media = (nota1 + nota2) / 2

if nota1 and nota2:
    if 9 < media <= 10:
        conceito ='A'
    elif 7.5 < media <= 10:
        conceito = 'B'
    elif 6 < media <=7.5:
        conceito = 'C'
    elif 4 < media <=6:
        conceito = 'D'
    elif media <= 4:
        conceito = 'E'
else:
    print('ERRO!! Preencha todos os campos!')
print(f'A sua média é de: {media}')
print(f'O conceito é: {conceito}')
# Out:
# A sua média é de: 9.25
# O conceito é: A

# %% [markdown]
# #### 15. Você está construindo um calendário para controlar dias de trabalho a pedido do RH. Nessa construção, você vai precisar definir quais anos são bissextos e quais não são, para montar o calendário de forma correta. Faça um Programa que peça um número correspondente a um determinado ano e em seguida informe se este ano é ou não bissexto.
# <pre>
# Dica para determinar se um ano é bissexto:
# - São bissextos todos os anos múltiplos de 400, p.ex.: 1600, 2000, 2400, 2800...
# - São bissextos todos os múltiplos de 4, exceto se for múltiplo de 100 mas não de 400,
# p.ex.: 1996, 2000, 2004, 2008, 2012, 2016, 2020, 2024, 2028...
# - Não são bissextos todos os demais anos.<br>
# ex1: 2004 é múltiplo de 4, mas não é múltiplo de 100, então é bissexto.
# ex2: 2000 é múltiplo de 4, mas é múltiplo de 100, só que também é multiplo de 400, então é bissexto (porque todo ano múltiplo de 400 é bissexto, independente do resto).
# ex3: 1900 é múltiplo de 4, é múltiplo de 100, mas não é múltiplo de 400, então não é bissexto
#
# </pre>
#
# Dica: lembre que: numero % 4 é o resto da divisão do número por 4, ex: 10 % 3 = 1 (já que 10/3 = 3 e resta 1)

# %%
ano = int(input('Informe p ano:'))

if (ano % 4 == 0 and ano % 100 !=0) or ano % 400 == 0:
    print(f'O ano é {ano} e é ano bissexto')
else:
    print(f'O ano é {ano} e não é ano bissexto')
# Out:
# O ano é 2023 e não é ano bissexto

# %% [markdown]
# #### 16. Faça um Programa para leitura de três notas parciais de um aluno. O programa deve calcular a média alcançada por aluno e presentar:
# <pre>
# A mensagem "Aprovado", se a média for maior ou igual a 7, com a respectiva média alcançada;
# A mensagem "Reprovado", se a média for menor do que 7, com a respectiva média alcançada;
# A mensagem "Aprovado com Distinção", se a média for igual a 10.
# </pre>

# %%
nota1 = float(input('Digite a primeira nota: '))
nota2 = float(input('Digite a segunda nota: '))
nota3 = float(input('Digite a terceira nota: '))

media = (nota1 + nota2 + nota3) / 3

if nota1 and nota2 and nota3:
    print(f'A sua nota é {media}')
    if media == 10:
        print ('Aprov8ado com distinção')
    elif media >= 7:
        print ('Aprovado')
    elif media < 7:
        print ('Reprovado')
else:
    print('ERRO!! Preencha todos os campos!')
# Out:
# A sua nota é 4.666666666666667
# Reprovado

# %% [markdown]
# #### 17. João Papo-de-Pescador, homem de bem, comprou um microcomputador para controlar o rendimento diário de seu trabalho. Toda vez que ele traz um peso de peixes maior que o estabelecido pelo regulamento de pesca do estado de São Paulo (50 quilos) deve pagar uma multa de R$ 4,00 por quilo excedente. João precisa que você faça um programa que leia a variável peso (peso de peixes) e calcule o excesso. Gravar na variável excesso a quantidade de quilos além do limite e na variável multa o valor da multa que João deverá pagar. Imprima os dados do programa com as mensagens adequadas.

# %%
peso = float(input('Informe o peso dos peixes: '))

if peso > 50:
    excedente = peso - 50
    multa = excedente * 4
    print('O peso é de {} KG, o excedente foi de {}, a multa será de {} R$.' .format(peso, excedente, multa))
else:
    print('O peso é de {} KG. Não há multa.' .format(peso))
# Out:
# O peso é de 69.854 KG, o excedente foi de 19.854, a multa será de 79.416 R$.
